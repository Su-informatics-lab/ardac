# %%
import os
import pandas as pd
from tqdm import tqdm

# %%
OUT_PATH = 'nodes'
SCHEMAS = 'node_template/submission_diagnosis_template.tsv'

# %%
#read the diagnosis node header
diagnosis_pd = pd.read_csv(SCHEMAS, sep = '\t')
diagnosis_pd.drop(index=diagnosis_pd.index[0], 
        axis=0, 
        inplace=True)
diagnosis_pd
# Out:
# Empty DataFrame
# ...

# %%
aki_pd = pd.read_csv('csv_datasets/ARDaC_Mortality_and_AKI_2022-10-24.csv')
aki_pd
# Out:
#      usubjid vital_status last_contact_date  death_date acute_kidney_injury  \
# 0      11001        alive        05/21/2019         NaN             unknown
# 1      11002        alive        05/21/2019         NaN             unknown
# 2      11003        alive        01/27/2020         NaN             unknown
# 3      11004        alive        06/04/2019         NaN             unknown
# 4      11006         dead        09/15/2019  2019-09-15             unknown
# ..       ...          ...               ...         ...                 ...
# 915    81152        alive        10/17/2022         NaN             unknown
# 916    81153        alive        10/17/2022         NaN             unknown
# 917    81154        alive        10/17/2022         NaN             unknown
# 918    81155        alive        10/17/2022         NaN             unknown
# 919    81156        alive        10/17/2022         NaN             unknown
#
#     aki_date
# 0        NaN
# 1        NaN
# ...
